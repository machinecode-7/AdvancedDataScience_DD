# %%
import pandas as pd

# %%
data = pd.read_csv('homelessness.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# columns in our dataframe
data.columns
# Out:
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='object')

# %%
#To drop a column
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data

# %%
data.to_csv('homelessness_updated.csv')

# %%
data.columns
# Out:
# Index(['region', 'state', 'individuals', 'family_members', 'state_pop'], dtype='object')

# %%
data.head()
# Out:
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 1             Pacific      Alaska       1434.0           582.0     735139
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 3  West South Central    Arkansas       2280.0           432.0    3009733
# 4             Pacific  California     109008.0         20964.0   39461588

# %%
data.head(10)
# Out:
#                region                 state  individuals  family_members  \
# 0  East South Central               Alabama       2570.0           864.0
# 1             Pacific                Alaska       1434.0           582.0
# 2            Mountain               Arizona       7259.0          2606.0
# 3  West South Central              Arkansas       2280.0           432.0
# 4             Pacific            California     109008.0         20964.0
# 5            Mountain              Colorado       7607.0          3250.0
# 6         New England           Connecticut       2280.0          1696.0
# 7      South Atlantic              Delaware        708.0           374.0
# 8      South Atlantic  District of Columbia       3770.0          3134.0
# 9      South Atlantic               Florida      21443.0          9587.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588
# 5    5691287
# 6    3571520
# 7     965479
# 8     701547
# 9   21244317

# %%
data.shape #(rows,columns)
# Out:
# (51, 5)

# %%
data.describe()
# Out:
#          individuals  family_members     state_pop
# count      51.000000       51.000000  5.100000e+01
# mean     7225.784314     3504.882353  6.405637e+06
# std     15991.025083     7805.411811  7.327258e+06
# min       434.000000       75.000000  5.776010e+05
# 25%      1446.500000      592.000000  1.777414e+06
# 50%      3082.000000     1482.000000  4.461153e+06
# 75%      6781.500000     3196.000000  7.340946e+06
# max    109008.000000    52070.000000  3.946159e+07

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          51 non-null     object
#  1   state           51 non-null     object
#  2   individuals     51 non-null     float64
#  3   family_members  51 non-null     float64
#  4   state_pop       51 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.1+ KB

# %%
data.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %%
data.values
# Out:
# array([['East South Central', 'Alabama', 2570.0, 864.0, 4887681],
#        ['Pacific', 'Alaska', 1434.0, 582.0, 735139],
#        ['Mountain', 'Arizona', 7259.0, 2606.0, 7158024],
#        ['West South Central', 'Arkansas', 2280.0, 432.0, 3009733],
#        ['Pacific', 'California', 109008.0, 20964.0, 39461588],
#        ['Mountain', 'Colorado', 7607.0, 3250.0, 5691287],
#        ['New England', 'Connecticut', 2280.0, 1696.0, 3571520],
#        ['South Atlantic', 'Delaware', 708.0, 374.0, 965479],
#        ['South Atlantic', 'District of Columbia', 3770.0, 3134.0, 701547],
#        ['South Atlantic', 'Florida', 21443.0, 9587.0, 21244317],
#        ['South Atlantic', 'Georgia', 6943.0, 2556.0, 10511131],
#        ['Pacific', 'Hawaii', 4131.0, 2399.0, 1420593],
#        ['Mountain', 'Idaho', 1297.0, 715.0, 1750536],
#        ['East North Central', 'Illinois', 6752.0, 3891.0, 12723071],
#        ['East North Central', 'Indiana', 3776.0, 1482.0, 6695497],
# ...

# %%
data.head(10)
# Out:
#                region                 state  individuals  family_members  \
# 0  East South Central               Alabama       2570.0           864.0
# 1             Pacific                Alaska       1434.0           582.0
# 2            Mountain               Arizona       7259.0          2606.0
# 3  West South Central              Arkansas       2280.0           432.0
# 4             Pacific            California     109008.0         20964.0
# 5            Mountain              Colorado       7607.0          3250.0
# 6         New England           Connecticut       2280.0          1696.0
# 7      South Atlantic              Delaware        708.0           374.0
# 8      South Atlantic  District of Columbia       3770.0          3134.0
# 9      South Atlantic               Florida      21443.0          9587.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588
# 5    5691287
# 6    3571520
# 7     965479
# 8     701547
# 9   21244317

# %%
data.sort_values('state_pop')
# Out:
#                 region                 state  individuals  family_members  \
# 50            Mountain               Wyoming        434.0           205.0
# 45         New England               Vermont        780.0           511.0
# 8       South Atlantic  District of Columbia       3770.0          3134.0
# 1              Pacific                Alaska       1434.0           582.0
# 34  West North Central          North Dakota        467.0            75.0
# 41  West North Central          South Dakota        836.0           323.0
# 7       South Atlantic              Delaware        708.0           374.0
# 39         New England          Rhode Island        747.0           354.0
# 26            Mountain               Montana        983.0           422.0
# 19         New England                 Maine       1450.0          1066.0
# 29         New England         New Hampshire        835.0           615.0
# 11             Pacific                Hawaii       4131.0          2399.0
# ...

# %%
data.sort_values('state_pop',ascending=False)
# Out:
#                 region                 state  individuals  family_members  \
# 4              Pacific            California     109008.0         20964.0
# 43  West South Central                 Texas      19199.0          6111.0
# 9       South Atlantic               Florida      21443.0          9587.0
# 32        Mid-Atlantic              New York      39827.0         52070.0
# 38        Mid-Atlantic          Pennsylvania       8163.0          5349.0
# 13  East North Central              Illinois       6752.0          3891.0
# 35  East North Central                  Ohio       6929.0          3320.0
# 10      South Atlantic               Georgia       6943.0          2556.0
# 33      South Atlantic        North Carolina       6451.0          2817.0
# 22  East North Central              Michigan       5209.0          3142.0
# 30        Mid-Atlantic            New Jersey       6048.0          3350.0
# 46      South Atlantic              Virginia       3928.0          2047.0
# ...

# %%
data.sort_values(['state_pop', 'region'])
# Out:
#                 region                 state  individuals  family_members  \
# 50            Mountain               Wyoming        434.0           205.0
# 45         New England               Vermont        780.0           511.0
# 8       South Atlantic  District of Columbia       3770.0          3134.0
# 1              Pacific                Alaska       1434.0           582.0
# 34  West North Central          North Dakota        467.0            75.0
# 41  West North Central          South Dakota        836.0           323.0
# 7       South Atlantic              Delaware        708.0           374.0
# 39         New England          Rhode Island        747.0           354.0
# 26            Mountain               Montana        983.0           422.0
# 19         New England                 Maine       1450.0          1066.0
# 29         New England         New Hampshire        835.0           615.0
# 11             Pacific                Hawaii       4131.0          2399.0
# ...

# %%
data.sort_values(['state_pop', 'region'], ascending=[True, False])
# Out:
#                 region                 state  individuals  family_members  \
# 50            Mountain               Wyoming        434.0           205.0
# 45         New England               Vermont        780.0           511.0
# 8       South Atlantic  District of Columbia       3770.0          3134.0
# 1              Pacific                Alaska       1434.0           582.0
# 34  West North Central          North Dakota        467.0            75.0
# 41  West North Central          South Dakota        836.0           323.0
# 7       South Atlantic              Delaware        708.0           374.0
# 39         New England          Rhode Island        747.0           354.0
# 26            Mountain               Montana        983.0           422.0
# 19         New England                 Maine       1450.0          1066.0
# 29         New England         New Hampshire        835.0           615.0
# 11             Pacific                Hawaii       4131.0          2399.0
# ...

# %%
data['region']
# Out:
# 0     East South Central
# 1                Pacific
# 2               Mountain
# 3     West South Central
# 4                Pacific
# 5               Mountain
# 6            New England
# 7         South Atlantic
# 8         South Atlantic
# 9         South Atlantic
# 10        South Atlantic
# 11               Pacific
# 12              Mountain
# 13    East North Central
# 14    East North Central
# 15    West North Central
# 16    West North Central
# 17    East South Central
# 18    West South Central
# 19           New England
# 20        South Atlantic
# 21           New England
# 22    East North Central
# 23    West North Central
# 24    East South Central
# 25    West North Central
# 26              Mountain
# 27    West North Central
# 28              Mountain
# 29           New England
# 30          Mid-Atlantic
# 31              Mountain
# 32          Mid-Atlantic
# 33        South Atlantic
# 34    West North Central
# 35    East North Central
# 36    West South Central
# ...

# %%
data[['region','state']]
# Out:
#                 region                 state
# 0   East South Central               Alabama
# 1              Pacific                Alaska
# 2             Mountain               Arizona
# 3   West South Central              Arkansas
# 4              Pacific            California
# 5             Mountain              Colorado
# 6          New England           Connecticut
# 7       South Atlantic              Delaware
# 8       South Atlantic  District of Columbia
# 9       South Atlantic               Florida
# 10      South Atlantic               Georgia
# 11             Pacific                Hawaii
# 12            Mountain                 Idaho
# 13  East North Central              Illinois
# 14  East North Central               Indiana
# 15  West North Central                  Iowa
# 16  West North Central                Kansas
# 17  East South Central              Kentucky
# 18  West South Central             Louisiana
# 19         New England                 Maine
# ...

# %%
data['state_pop'] > 1000000
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34    False
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41    False
# 42     True
# 43     True
# 44     True
# 45    False
# 46     True
# 47     True
# 48     True
# 49     True
# 50    False
# Name: state_pop, dtype: bool

# %%
#dataframe[condition]
data[data['state_pop'] > 1000000]
# Out:
#                 region           state  individuals  family_members  state_pop
# 0   East South Central         Alabama       2570.0           864.0    4887681
# 2             Mountain         Arizona       7259.0          2606.0    7158024
# 3   West South Central        Arkansas       2280.0           432.0    3009733
# 4              Pacific      California     109008.0         20964.0   39461588
# 5             Mountain        Colorado       7607.0          3250.0    5691287
# 6          New England     Connecticut       2280.0          1696.0    3571520
# 9       South Atlantic         Florida      21443.0          9587.0   21244317
# 10      South Atlantic         Georgia       6943.0          2556.0   10511131
# 11             Pacific          Hawaii       4131.0          2399.0    1420593
# 12            Mountain           Idaho       1297.0           715.0    1750536
# 13  East North Central        Illinois       6752.0          3891.0   12723071
# ...

# %%
data[data['state_pop'] > 1000000].shape
# Out:
# (44, 5)

# %%
data[data['region']=='Pacific']
# Out:
#      region       state  individuals  family_members  state_pop
# 1   Pacific      Alaska       1434.0           582.0     735139
# 4   Pacific  California     109008.0         20964.0   39461588
# 11  Pacific      Hawaii       4131.0          2399.0    1420593
# 37  Pacific      Oregon      11139.0          3337.0    4181886
# 47  Pacific  Washington      16424.0          5880.0    7523869

# %%
(data['region']=='Pacific')  & (data['state_pop'] > 1000000)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47     True
# 48    False
# 49    False
# 50    False
# dtype: bool

# %%
data[(data['region']=='Pacific')  & (data['state_pop'] > 1000000)]
# Out:
#      region       state  individuals  family_members  state_pop
# 4   Pacific  California     109008.0         20964.0   39461588
# 11  Pacific      Hawaii       4131.0          2399.0    1420593
# 37  Pacific      Oregon      11139.0          3337.0    4181886
# 47  Pacific  Washington      16424.0          5880.0    7523869

# %%
data[data['region'].isin(['Pacific','Mountain'])]
# Out:
#       region       state  individuals  family_members  state_pop
# 1    Pacific      Alaska       1434.0           582.0     735139
# 2   Mountain     Arizona       7259.0          2606.0    7158024
# 4    Pacific  California     109008.0         20964.0   39461588
# 5   Mountain    Colorado       7607.0          3250.0    5691287
# 11   Pacific      Hawaii       4131.0          2399.0    1420593
# 12  Mountain       Idaho       1297.0           715.0    1750536
# 26  Mountain     Montana        983.0           422.0    1060665
# 28  Mountain      Nevada       7058.0           486.0    3027341
# 31  Mountain  New Mexico       1949.0           602.0    2092741
# 37   Pacific      Oregon      11139.0          3337.0    4181886
# 44  Mountain        Utah       1904.0           972.0    3153550
# 47   Pacific  Washington      16424.0          5880.0    7523869
# 50  Mountain     Wyoming        434.0           205.0     577601

# %%
data['state_pop_million'] = data['state_pop'] / 1000000

# %%
data
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama       2570.0           864.0
# 1              Pacific                Alaska       1434.0           582.0
# 2             Mountain               Arizona       7259.0          2606.0
# 3   West South Central              Arkansas       2280.0           432.0
# 4              Pacific            California     109008.0         20964.0
# 5             Mountain              Colorado       7607.0          3250.0
# 6          New England           Connecticut       2280.0          1696.0
# 7       South Atlantic              Delaware        708.0           374.0
# 8       South Atlantic  District of Columbia       3770.0          3134.0
# 9       South Atlantic               Florida      21443.0          9587.0
# 10      South Atlantic               Georgia       6943.0          2556.0
# 11             Pacific                Hawaii       4131.0          2399.0
# ...

# %%
data['state_pop'].median()
# Out:
# 4461153.0

# %%
data['state_pop'].mean()
# Out:
# 6405637.274509804

# %%
data['state_pop'].max()
# Out:
# 39461588

# %%
def pct95(column):
    return column.quantile(0.95)

def pct70(column):
    return column.quantile(0.70)

# %%
data['state_pop'].agg(pct95)
# Out:
# 20387334.0

# %%
data['state_pop'].agg([pct95, pct70])
# Out:
# pct95    20387334.0
# pct70     6771631.0
# Name: state_pop, dtype: float64

# %%
data.drop_duplicates(subset='region')
data.drop_duplicates(subset='region',keep='last')
# Out:
#                 region          state  individuals  family_members  state_pop  \
# 38        Mid-Atlantic   Pennsylvania       8163.0          5349.0   12800922
# 41  West North Central   South Dakota        836.0           323.0     878698
# 42  East South Central      Tennessee       6139.0          1744.0    6771631
# 43  West South Central          Texas      19199.0          6111.0   28628666
# 45         New England        Vermont        780.0           511.0     624358
# 47             Pacific     Washington      16424.0          5880.0    7523869
# 48      South Atlantic  West Virginia       1021.0           222.0    1804291
# 49  East North Central      Wisconsin       2740.0          2167.0    5807406
# 50            Mountain        Wyoming        434.0           205.0     577601
#
#     state_pop_million
# 38          12.800922
# 41           0.878698
# 42           6.771631
# 43          28.628666
# 45           0.624358
# 47           7.523869
# 48           1.804291
# ...

# %%
data.drop_duplicates(subset=['region','state'])
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama       2570.0           864.0
# 1              Pacific                Alaska       1434.0           582.0
# 2             Mountain               Arizona       7259.0          2606.0
# 3   West South Central              Arkansas       2280.0           432.0
# 4              Pacific            California     109008.0         20964.0
# 5             Mountain              Colorado       7607.0          3250.0
# 6          New England           Connecticut       2280.0          1696.0
# 7       South Atlantic              Delaware        708.0           374.0
# 8       South Atlantic  District of Columbia       3770.0          3134.0
# 9       South Atlantic               Florida      21443.0          9587.0
# 10      South Atlantic               Georgia       6943.0          2556.0
# 11             Pacific                Hawaii       4131.0          2399.0
# ...

# %%
data['region'].value_counts()
# Out:
# South Atlantic        9
# Mountain              8
# West North Central    7
# New England           6
# Pacific               5
# East North Central    5
# East South Central    4
# West South Central    4
# Mid-Atlantic          3
# Name: region, dtype: int64

# %%
data['state'].value_counts()
# Out:
# Alabama                 1
# Pennsylvania            1
# Nevada                  1
# New Hampshire           1
# New Jersey              1
# New Mexico              1
# New York                1
# North Carolina          1
# North Dakota            1
# Ohio                    1
# Oklahoma                1
# Oregon                  1
# Rhode Island            1
# Montana                 1
# South Carolina          1
# South Dakota            1
# Tennessee               1
# Texas                   1
# Utah                    1
# Vermont                 1
# Virginia                1
# Washington              1
# West Virginia           1
# Wisconsin               1
# Nebraska                1
# Missouri                1
# Alaska                  1
# Idaho                   1
# Arizona                 1
# Arkansas                1
# California              1
# Colorado                1
# Connecticut             1
# Delaware                1
# District of Columbia    1
# ...

# %%
data['region'].value_counts(sort=True)
# Out:
# South Atlantic        9
# Mountain              8
# West North Central    7
# New England           6
# Pacific               5
# East North Central    5
# East South Central    4
# West South Central    4
# Mid-Atlantic          3
# Name: region, dtype: int64
